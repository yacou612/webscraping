# %%
import pandas as pd
df = pd.read_csv('company_list_v2.csv')
df
# Out:
#                                           Company Name  \
# 0    AICI (AGENCE INTERNATIONALE DE COMMERCIALISATI...
# 1                                    AKIDOM IMMOBILIER
# 2    TSCI IMMOBILIER GROUP (TOUS SERVICES COMPANY I...
# 3                                     GROUPE EZIP SARL
# 4                                       A2K IMMOBILIER
# ..                                                 ...
# 114                                   TWINS IMMOBILIER
# 115                                        VIMMOBILIER
# 116                                   YAPGI IMMOBILIER
# 117                                  YIRIMA IMMOBILIER
# 118                                               YSYS
#
#                                 Website Link  \
# 0                       http:\/\/www.aici.ci
# 1             https:\/\/www.akidomimmo.com\/
# 2                      https:\/\/ts-ci.com\/
# 3               https:\/\/www.ezipimmo.com\/
# 4              http:\/\/www.a2kimmobilier.ci
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the 'scrape' column to string type
df['scrape'] = df['scrape'].astype(str)

# Set the colors for the bars
colors = {'0': 'salmon', '1': 'turquoise'}

# Create the count plot
sns.countplot(data=df, x='scrape', palette=colors)

# Set plot labels and title
plt.xlabel('Scrape Value')
plt.ylabel('Count')
plt.title('Histogram of Scrape Column')

# Show the plot
plt.show()
# Out:
# /var/folders/84/qq95gfbj1s5d3j1zwg6g04v00000gn/T/ipykernel_68722/704114075.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='scrape', palette=colors)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the 'scrape' column to string type
df['scrape'] = df['scrape'].astype(str)

# Set the colors for the bars
colors = {'0': 'salmon', '1': 'turquoise'}

# Create the count plot
ax = sns.countplot(data=df, x='scrape', palette=colors)

# Annotate the bars with the count
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12, color='black')

# Set plot labels and title
plt.xlabel('Scrape Value')
plt.ylabel('Count')
plt.title('Histogram of Scrape Column')

# Show the plot
plt.show()
# Out:
# /var/folders/84/qq95gfbj1s5d3j1zwg6g04v00000gn/T/ipykernel_68722/2832631947.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='scrape', palette=colors)

# %%
# Filter the DataFrame to include only rows where 'scrape' is 1
final_scrape = df[df['scrape'] == '1']  # Assuming 'scrape' is a string in this example

# Write the filtered DataFrame to a CSV file
final_scrape.to_csv('sites_to_scrappe.csv', index=False)

# %%
final_scrape = df[df['scrape'] == '1'] 

# Write the filtered DataFrame to a CSV file
final_scrape.to_csv('sites_to_scrappe.csv', index=False)

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(final_scrape):
    # Drop columns: 'comments', 'Website Link'
    final_scrape = final_scrape.drop(columns=['comments', 'Website Link'])
    # Rename column 'update_link' to 'link'
    final_scrape = final_scrape.rename(columns={'update_link': 'link'})
    return final_scrape

final_scrape_clean = clean_data(final_scrape.copy())
final_scrape_clean.head()
# Out:
#                                         Company Name  \
# 0  AICI (AGENCE INTERNATIONALE DE COMMERCIALISATI...
# 1                                  AKIDOM IMMOBILIER
# 2  TSCI IMMOBILIER GROUP (TOUS SERVICES COMPANY I...
# 3                                   GROUPE EZIP SARL
# 4                                     A2K IMMOBILIER
#
#                             link scrape
# 0             https://aici.ci/fr      1
# 1   https://www.akidomimmo.com//      1
# 2             https://ts-ci.com/      1
# 3      https://www.ezipimmo.com/      1
# 4  https://www.a2kimmobilier.ci/      1

# %%
# Write the filtered DataFrame to a CSV file
final_scrape_clean.to_csv('sites_to_scrappe.csv', index=False)
